# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("FraudDetection") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/08/15 21:43:46 WARN Utils: Your hostname, NolanPC, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/08/15 21:43:46 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/15 21:43:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/08/15 21:43:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df = spark.read.parquet("/home/nolan/fraud/data/processed")
df.orderBy("timestamp", ascending=False).show(5)
# Out:
# [Stage 5:==================================================>   (295 + 16) / 313]
# +--------------------+-------------+------+--------------------+--------+------------------+---------+------------------+------------------+------------------+-------------------+------------------+--------------------+-------------+----------------------+--------------+-------------+---------+
# |      transaction_id|     merchant|amount|           timestamp|is_fraud|        log_amount|txn_index|      user_cum_sum|      user_cum_avg|      user_cum_std|amount_to_avg_ratio|amount_x_txn_index|             prev_ts|time_diff_sec|log_amount_x_time_diff|merchant_index| merchant_ohe|  user_id|
# +--------------------+-------------+------+--------------------+--------+------------------+---------+------------------+------------------+------------------+-------------------+------------------+--------------------+-------------+----------------------+--------------+-------------+---------+
# |97d8a706-61dd-45a...|subscriptions| 14.93|2025-08-15 19:52:...|       0| 2.768204123921957|      293| 95596.08650715956|326.26650685037396|  441.100868799778|0.04576013670041458|           4374.49|2025-08-15 19:51:...|           12|     33.21844948706348|           3.0|(5,[3],[1.0])|user_5904|
# |34f43a34-aa64-4ca...|     clothing| 211.6|2025-08-15 19:52:...|       0| 5.359412465907847|      296| 90466.31355302157| 305.6294376791269| 416.2273289194554| 0.6923416831653898|           62633.6|2025-08-15 19:50:...|           71|    380.51828507945714|           2.0|(5,[2],[1.0])|user_8700|
# |db67e250-7930-424...|      grocery| 31.09|2025-08-15 19:52:...|       0|3.4685444551217657|      332|105585.20262459689| 318.0277187487858|478.40850905796424| 0.0977587740608221|          10321.88|2025-08-15 19:51:...|           21|     72.83943355755707|           0.0|(5,[0],[1.0])|user_1075|
# |0e4d0ae7-81be-497...|      grocery| 88.71|2025-08-15 19:52:...|       0| 4.496582245571192|      316| 89356.86152437441|282.77487824169117| 389.8810188905123| 0.3137124494152059|28032.359999999997|2025-08-15 19:51:...|           35|    157.38037859499173|           0.0|(5,[0],[1.0])|user_2592|
# |569a37c6-7780-449...|  electronics|777.64|2025-08-15 19:52:...|       0| 6.657548808118238|      308| 99706.89002413087| 323.7236689095158| 476.5277145313247| 2.4021721989539984|         239513.12|2025-08-15 19:52:...|            7|     46.60284165682767|           1.0|(5,[1],[1.0])|user_7652|
# +--------------------+-------------+------+--------------------+--------+------------------+---------+------------------+------------------+------------------+-------------------+------------------+--------------------+-------------+----------------------+--------------+-------------+---------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col

counts = df.groupBy("is_fraud").count().collect()
count_fraud = [row["count"] for row in counts if row["is_fraud"] == 1][0]
count_nonfraud = [row["count"] for row in counts if row["is_fraud"] == 0][0]

weight_fraud = count_nonfraud / (count_nonfraud + count_nonfraud)
weight_nonfraud= 1.0

df = df.withColumn("class_weight", col("is_fraud") * weight_fraud + (1 - col("is_fraud")) * weight_nonfraud)
df.show(5)
# Out:
# +--------------------+-----------+------+--------------------+--------+------------------+---------+------------+------------------+------------------+-------------------+------------------+--------------------+-------------+----------------------+--------------+-------------+---------+------------+
# |      transaction_id|   merchant|amount|           timestamp|is_fraud|        log_amount|txn_index|user_cum_sum|      user_cum_avg|      user_cum_std|amount_to_avg_ratio|amount_x_txn_index|             prev_ts|time_diff_sec|log_amount_x_time_diff|merchant_index| merchant_ohe|  user_id|class_weight|
# +--------------------+-----------+------+--------------------+--------+------------------+---------+------------+------------------+------------------+-------------------+------------------+--------------------+-------------+----------------------+--------------+-------------+---------+------------+
# |69f97ba2-1b54-4a7...|     travel|574.48|2025-08-15 18:14:...|       0| 6.355204475168832|        1|      574.48|            574.48|               0.0| 0.9999999982592954|            574.48|                NULL|            0|                   0.0|           4.0|(5,[4],[1.0])|user_1498|         1.0|
# |ffef8203-0c09-4da...|   clothing| 32.12|2025-08-15 18:14:...|       0| 3.500137329517059|        2|       606.6|             303.3|383.50643384433596|0.10590174709560914|             64.24|2025-08-15 18:14:...|           25|     87.50343323792647|           2.0|(5,[2],[1.0])|user_1498|         1.0|
# |0df090eb-7175-4ee...|restaurants| 25.35|2025-08-15 18:14:...|       0|3.2714682749873716|        3|      631.95|            210.65| 315.1042048275459|0.12034179862168622| 76.05000000000001|2025-08-15 18:14:...|            4|    13.085873099949486|           5.0|    (5,[],[])|user_1498|         1.0|
# |7b49a13c-1f60-48e...|electronics|537.51|2025-08-15 18:14:...|       0| 6.288806066526156|        4|     1169.46|           292.365|304.80016103451567| 1.8384895529954353|           2150.04|2025-08-15 18:14:...|           12|     75.46567279831388|           1.0|(5,[1],[1.0])|user_1498|         1.0|
# |d088a5ae-65a4-4c3...|restaurants|108.18|2025-08-15 18:15:...|       0| 4.692997896353612|        5|     1277.64|255.52800000000002|276.51794963437726| 0.4233586909326622| 540.9000000000001|2025-08-15 18:14:...|            1|     4.692997896353612|           5.0|    (5,[],[])|user_1498|         1.0|
# +--------------------+-----------+------+--------------------+--------+------------------+---------+------------+------------------+------------------+-------------------+------------------+--------------------+-------------+----------------------+--------------+-------------+---------+------------+
# only showing top 5 rows

# %%
from pyspark.ml.feature import VectorAssembler

numeric_cols = [
    "amount", "log_amount", "txn_index", "user_cum_sum", "user_cum_avg", "user_cum_std", "amount_to_avg_ratio", "amount_x_txn_index", "time_diff_sec", "log_amount_x_time_diff"
]

assembler = VectorAssembler(
    inputCols=numeric_cols + ["merchant_ohe"],
    outputCol="features"
)

df_model = assembler.transform(df)

# %%
train_df, test_df = df_model.randomSplit([0.8, 0.2], seed=33)

# %%
from pyspark.ml.classification import RandomForestClassifier

rf = RandomForestClassifier(
    featuresCol="features",
    labelCol="is_fraud",
    weightCol="class_weight",
    numTrees=100
)

model = rf.fit(train_df)
# Out:
# 25/08/15 21:56:31 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_83 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_83 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_85 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_85 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_87 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_87 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_98 in memory.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_83 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_92 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_92 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_87 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_90 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_93 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_90 to disk instead.
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_93 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_94 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_96 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_94 to disk instead.
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_96 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_91 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_91 to disk instead.
# 25/08/15 21:57:00 WARN MemoryStore: Not enough space to cache rdd_71_98 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:00 WARN BlockManager: Persisting block rdd_71_98 to disk instead.
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_98 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_100 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_111 in memory.
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_101 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_104 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_103 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_102 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_100 to disk instead.
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_103 to disk instead.
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_101 to disk instead.
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_102 to disk instead.
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_104 to disk instead.
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_103 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_102 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_105 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_110 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_110 to disk instead.
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_100 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_104 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_107 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_101 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_105 to disk instead.
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_107 to disk instead.
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_111 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_111 to disk instead.
# 25/08/15 21:57:01 WARN MemoryStore: Not enough space to cache rdd_71_114 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:01 WARN BlockManager: Persisting block rdd_71_114 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_117 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_117 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_120 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_120 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_117 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_122 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_122 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_125 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_125 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_127 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_127 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_129 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_129 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_130 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:02 WARN BlockManager: Persisting block rdd_71_130 to disk instead.
# 25/08/15 21:57:02 WARN MemoryStore: Not enough space to cache rdd_71_128 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_138 in memory.
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_128 to disk instead.
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_131 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_125 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_132 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_134 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_134 to disk instead.
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_131 to disk instead.
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_132 to disk instead.
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_128 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_136 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_138 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_138 to disk instead.
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_136 to disk instead.
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_135 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:03 WARN BlockManager: Persisting block rdd_71_135 to disk instead.
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_132 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_154 in memory.
# 25/08/15 21:57:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_156 in memory.
# 25/08/15 21:57:03 WARN MemoryStore: Not enough space to cache rdd_71_143 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_146 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_149 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_157 in memory.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_147 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_145 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_143 to disk instead.
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_149 to disk instead.
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_147 to disk instead.
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_145 to disk instead.
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_146 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_156 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_156 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_154 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_154 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_145 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_148 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_148 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_146 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_157 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_157 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_152 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_152 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_154 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_159 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_159 to disk instead.
# 25/08/15 21:57:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_171 in memory.
# 25/08/15 21:57:04 WARN MemoryStore: Not enough space to cache rdd_71_161 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:04 WARN BlockManager: Persisting block rdd_71_161 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_163 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_159 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_163 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_171 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_171 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_170 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_170 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_168 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_176 in memory.
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_168 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_172 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_172 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_171 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_183 in memory.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_173 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_174 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_173 to disk instead.
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_174 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_172 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_176 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_176 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_174 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_180 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_180 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_175 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:05 WARN BlockManager: Persisting block rdd_71_175 to disk instead.
# 25/08/15 21:57:05 WARN MemoryStore: Not enough space to cache rdd_71_183 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_183 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_185 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_184 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_185 to disk instead.
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_184 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_183 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_186 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_186 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_187 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_187 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_197 in memory.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_184 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_185 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_186 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_188 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_188 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_199 in memory.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_189 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_189 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_192 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_192 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_194 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_193 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_193 to disk instead.
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_194 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_197 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_203 in memory.
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_197 to disk instead.
# 25/08/15 21:57:06 WARN MemoryStore: Not enough space to cache rdd_71_199 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:06 WARN BlockManager: Persisting block rdd_71_199 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_197 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_200 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_203 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_203 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_202 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_200 to disk instead.
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_202 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_205 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_206 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_205 to disk instead.
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_206 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_203 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_204 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_204 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_200 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_212 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_212 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_214 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_209 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_209 to disk instead.
# 25/08/15 21:57:07 WARN BlockManager: Persisting block rdd_71_214 to disk instead.
# 25/08/15 21:57:07 WARN MemoryStore: Not enough space to cache rdd_71_212 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_209 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_217 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_217 to disk instead.
# 25/08/15 21:57:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_232 in memory.
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_220 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_219 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_221 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_231 in memory.
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_220 to disk instead.
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_219 to disk instead.
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_221 to disk instead.
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_232 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_232 to disk instead.
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_227 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_231 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_226 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_227 to disk instead.
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_228 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_226 to disk instead.
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_228 to disk instead.
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_231 to disk instead.
# 25/08/15 21:57:08 WARN MemoryStore: Not enough space to cache rdd_71_225 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:08 WARN BlockManager: Persisting block rdd_71_225 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_237 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_237 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_235 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_235 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_240 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_240 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_240 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_255 in memory.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_245 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_245 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_246 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_258 in memory.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_243 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_243 to disk instead.
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_246 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_248 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_248 to disk instead.
# 25/08/15 21:57:09 WARN MemoryStore: Not enough space to cache rdd_71_247 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:09 WARN BlockManager: Persisting block rdd_71_247 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_248 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_251 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_251 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_255 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_255 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_253 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_253 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_250 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_250 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_265 in memory.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_254 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_258 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_258 to disk instead.
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_254 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_273 in memory.
# 25/08/15 21:57:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_272 in memory.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_263 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_263 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_265 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_265 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_264 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_264 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_274 in memory.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_260 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_260 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_261 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:10 WARN BlockManager: Persisting block rdd_71_261 to disk instead.
# 25/08/15 21:57:10 WARN MemoryStore: Not enough space to cache rdd_71_264 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_273 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_273 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_276 in memory.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_265 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_268 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_270 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_268 to disk instead.
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_270 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_272 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_272 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_269 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_269 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_266 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_266 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_271 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_271 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_274 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_274 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_274 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:11 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_285 in memory.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_276 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_286 in memory.
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_276 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_289 in memory.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_280 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_279 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_280 to disk instead.
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_279 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_289 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_289 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_286 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_286 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_285 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:11 WARN BlockManager: Persisting block rdd_71_285 to disk instead.
# 25/08/15 21:57:11 WARN MemoryStore: Not enough space to cache rdd_71_279 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_295 in memory.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_284 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_284 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_304 in memory.
# 25/08/15 21:57:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_305 in memory.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_295 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_295 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_308 in memory.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_296 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_296 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_304 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_304 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_296 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_305 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_305 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_298 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_298 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_301 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_301 to disk instead.
# 25/08/15 21:57:12 WARN MemoryStore: Not enough space to cache rdd_71_302 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:12 WARN BlockManager: Persisting block rdd_71_302 to disk instead.
# 25/08/15 21:57:13 WARN MemoryStore: Not enough space to cache rdd_71_308 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:13 WARN BlockManager: Persisting block rdd_71_308 to disk instead.
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_2 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_9 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_11 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_8 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_12 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_15 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_14 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_1 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_5 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_4 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_10 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_13 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_0 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_6 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_7 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:14 WARN MemoryStore: Not enough space to cache rdd_71_3 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_22 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_19 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_27 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_27 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_17 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_20 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_21 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_28 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_28 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_25 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_24 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_23 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_26 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_30 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_30 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_29 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_29 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_32 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_34 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_33 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_40 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_40 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_38 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_35 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_39 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_36 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_37 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_41 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_41 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_42 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_42 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_45 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_46 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_49 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_50 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_51 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_51 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_47 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_52 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_52 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_48 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_53 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_55 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_57 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_54 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_57 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_59 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_58 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_59 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_58 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_62 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_61 in memory.
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_62 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_61 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:15 WARN MemoryStore: Not enough space to cache rdd_71_60 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_67 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_67 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_66 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_66 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_56 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_65 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_68 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_68 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_63 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_64 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_69 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_69 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_70 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_70 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_72 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_72 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_71 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_74 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_74 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_73 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_76 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_76 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_80 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_75 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_80 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_81 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_81 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_78 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_79 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_82 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_84 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_84 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_85 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_85 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_83 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_89 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_89 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_88 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_87 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_91 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_91 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_90 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_90 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_92 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_92 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_93 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_93 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_94 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_94 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_86 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_95 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_95 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_96 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_96 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_97 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_97 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_98 in memory.
# 25/08/15 21:57:16 WARN MemoryStore: Not enough space to cache rdd_71_98 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_99 in memory.
# ...
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_128 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_128 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_131 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_132 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_131 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_132 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_127 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_126 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_130 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_129 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_133 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_133 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_135 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_135 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_136 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_136 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_134 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_138 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_138 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_139 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_139 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_140 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_137 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_140 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_141 in memory.
# 25/08/15 21:57:51 WARN MemoryStore: Not enough space to cache rdd_71_141 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_144 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_144 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_142 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_145 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_145 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_143 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_147 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_147 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_146 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_146 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_148 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_148 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_149 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_149 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_150 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_150 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_152 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_152 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_153 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_153 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_151 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_154 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_154 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_155 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_155 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_156 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_156 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_157 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_157 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_160 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_160 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_161 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_161 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_162 in memory.
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_162 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_159 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:52 WARN MemoryStore: Not enough space to cache rdd_71_158 in memory! (computed 2.4 MiB so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_163 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_163 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_164 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_164 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_165 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_165 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_166 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_166 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_167 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_167 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_168 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_168 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_170 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_169 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_172 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_172 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_171 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_171 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_173 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_174 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_176 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_176 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_175 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_175 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_177 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_177 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_178 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_178 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_179 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_180 in memory.
# 25/08/15 21:57:53 WARN MemoryStore: Not enough space to cache rdd_71_180 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_183 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_183 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_181 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_181 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_182 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_182 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_184 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_184 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_185 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_188 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_188 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_186 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_187 in memory! (computed 1550.8 KiB so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_189 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_189 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_190 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_191 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_195 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_195 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_194 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_194 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_196 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_196 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_198 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_198 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_197 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_197 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_71_203 in memory.
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_203 in memory! (computed 504.0 B so far)
# 25/08/15 21:57:54 WARN MemoryStore: Not enough space to cache rdd_71_200 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:55 WARN MemoryStore: Not enough space to cache rdd_71_209 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:55 WARN MemoryStore: Not enough space to cache rdd_71_212 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:57 WARN MemoryStore: Not enough space to cache rdd_71_240 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:57 WARN MemoryStore: Not enough space to cache rdd_71_248 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:57 WARN MemoryStore: Not enough space to cache rdd_71_264 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:57 WARN MemoryStore: Not enough space to cache rdd_71_265 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:58 WARN MemoryStore: Not enough space to cache rdd_71_274 in memory! (computed 1033.6 KiB so far)
# 25/08/15 21:57:58 WARN MemoryStore: Not enough space to cache rdd_71_279 in memory! (computed 3.7 MiB so far)
# 25/08/15 21:57:59 WARN MemoryStore: Not enough space to cache rdd_71_296 in memory! (computed 3.7 MiB so far)

# %%
preds = model.transform(test_df)
preds.select("is_fraud", "probability", "prediction").show(20)
# Out:
# +--------+--------------------+----------+
# |is_fraud|         probability|prediction|
# +--------+--------------------+----------+
# |       0|[0.99450337610762...|       0.0|
# |       0|[0.99477901771737...|       0.0|
# |       0|[0.99448156032218...|       0.0|
# |       0|[0.99471167439225...|       0.0|
# |       0|[0.99491742980412...|       0.0|
# |       0|[0.99487810075278...|       0.0|
# |       0|[0.99538075329297...|       0.0|
# |       0|[0.99683284589864...|       0.0|
# |       0|[0.99694814630829...|       0.0|
# |       0|[0.99491347917077...|       0.0|
# |       0|[0.99613870447263...|       0.0|
# |       0|[0.99647683388424...|       0.0|
# |       0|[0.99388807295998...|       0.0|
# |       0|[0.99539957150603...|       0.0|
# |       0|[0.99473203340797...|       0.0|
# |       0|[0.99153302525458...|       0.0|
# |       0|[0.99687834686575...|       0.0|
# |       0|[0.99543912783132...|       0.0|
# |       0|[0.99689881864985...|       0.0|
# |       0|[0.99478285420551...|       0.0|
# +--------+--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator(labelCol="is_fraud", metricName="areaUnderROC")
roc_auc = evaluator.evaluate(preds)
print(f"ROC_AUC: {roc_auc}")
# Out:
# ROC_AUC: 0.7792508593623445

# %%
preds.groupBy("is_fraud", "prediction").count().show()
# Out:
# [Stage 46:====================================================> (306 + 7) / 313]
# +--------+----------+------+
# |is_fraud|prediction| count|
# +--------+----------+------+
# |       1|       0.0|  5627|
# |       0|       0.0|593465|
# |       1|       1.0|   310|
# +--------+----------+------+
